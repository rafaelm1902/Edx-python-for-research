# %% [markdown]
# # 2.3.1: Introduction to Matplotlib and Pyplot

# %% [markdown]
# Matplotlib is a Python plotting library that
# produces publication-quality figures.
#
# Matplotlib is a very large library, and getting to know it well takes time.
# But often we don't need the full matplotlib library in our programs,
# and this is where Pyplot comes in handy.
#
# Pyplot is a collection of functions that make matplotlib work like Matlab
#
# Pyplot is especially useful for interactive work, for example, when you'd like to explore a dataset
# or visually examine your simulation results.
#
# We'll be using Pyplot in all our data visualizations.
# Pyplot provides what is sometimes called a state machine interface to matplotlib library.
#
# You can loosely think of it as a process where you create figures one at a time,
# and all commands affect the current figure and the current plot.

# %%
# to import the pyplot library, we imported as plt

import matplotlib.pyplot as plt

# %%
plt.plot([0,1,4,9,16]) # the list would be the y axis, which is then plotted on increments of 1 across the x axis

# %%
plt.plot([0,1,4,9,16]); # with semicolon we dont get the matplotlib object printed out at the top

# %%
plt.show # if not working in python shell, then we would need to issue the command show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np

x = np.linspace(0, 10, 20) # starting at 0, ends at 10, with 20 points, this is a vector

y = x**2 # I will define y as vector x but raising each element to the power of 2

# %%
x
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
y
# Out:
# array([  0.        ,   0.27700831,   1.10803324,   2.49307479,
#          4.43213296,   6.92520776,   9.97229917,  13.5734072 ,
#         17.72853186,  22.43767313,  27.70083102,  33.51800554,
#         39.88919668,  46.81440443,  54.29362881,  62.32686981,
#         70.91412742,  80.05540166,  89.75069252, 100.        ])

# %%
plt.plot(x,y); # x is x-axis, y is y-axis

# %%
# A keyword argument is an argument which is supplied to the function by explicitly naming each parameter
# and specifying its value.

# Two keyword arguments that are linewidth and markersize.

x = np.linspace(0,10,20)

y1 = x**2

y2 = x**1.5

plt.plot(x, y1, "bo-") # the third argument specifies to use blue circles and a solid line on the graph

# %%
plt.plot(x, y1, "bo-", linewidth = 2, markersize = 4) 
# linewidth has changed, and the size of the markers has also changed.

# %%
plt.plot(x, y1, "bo-", linewidth = 2, markersize = 12)

# %%
plt.plot(x, y1, "gs-", linewidth = 2, markersize = 12) # gs = green squares

# %%
plt.plot([0,1,2],[0,1,4],"rd-")

# %% [markdown]
# # 2.3.2: Customizing Your Plots

# %% [markdown]
# There are a few important elements that can be easily added to plots.
#
# we can add a legend with: legend()
#
# adjust axis with : axis()
#
# set axis labels with : xlabel(), ylabel
#
# save a figure using: savefig()

# %%
plt.plot(x, y1, "bo-", linewidth = 2, markersize = 12)
plt.plot(x, y2, "gs-", linewidth = 2, markersize = 12) 
plt.xlabel('X')
plt.ylabel('Y')
plt.axis([-0.5, 10.5, -5, 105]) # [xmin, xmax, ymin, ymax]
# Out:
# (-0.5, 10.5, -5.0, 105.0)

# %%
plt.plot(x, y1, "bo-", linewidth = 2, markersize = 12, label = "First") # label gives the name to the particular series
plt.plot(x, y2, "gs-", linewidth = 2, markersize = 12, label = "Second") 
plt.xlabel('X')
plt.ylabel('Y')
plt.axis([-0.5, 10.5, -5, 105]) # [xmin, xmax, ymin, ymax]
plt.legend(loc = "upper left")
plt.savefig("mypracticeplot.pdf")

# %% [markdown]
# # 2.3.3: Plotting Using Logarithmic Axes

# %% [markdown]
# The plt functions that I used to make logarithmic plots are the following:
#
# semilogx() plots the x-axes on a log scale and the y in the original scale;
#
# semilogy() plots the y-axes on the log scale and the x in the original scale;
#
# loglog() plots both x and y on logarithmic scales.

# %%
To understand why logarithmic plots are sometimes useful, let's take a quick look at the underlying math.
Consider a function of the form y is equal to x to the power of alpha. (y = x^a).
If alpha is equal to 1, that corresponds to a line that goes through the origin.
Alpha equal to half gives you the square root, and alpha equal to 2 gives us a parabola.

So the lesson here is that functions of the form y is equal to x to power alpha
show up as straight lines on a loglog() plot.
The exponent alpha is given by the slope of the line.

# %%
plt.loglog(x, y1, "bo-", linewidth = 2, markersize = 12, label = "First") # label gives the name to the particular series
plt.loglog(x, y2, "gs-", linewidth = 2, markersize = 12, label = "Second") 
plt.xlabel('X')
plt.ylabel('Y')
plt.axis([-0.5, 10.5, -5, 105]) # [xmin, xmax, ymin, ymax]
plt.legend(loc = "upper left")
plt.savefig("mypracticeplot.pdf")
# Out:
# C:\Users\Rafael\Miniconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   """
# C:\Users\Rafael\Miniconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   """

# %%
x = np.logspace(-1,1,40) # -1(my first point will be 0.1), end at 1(which is log(10) = 1, the endpoint is equal to 10), and 40 counts
y1 = x**2
y2 = x**1.5
plt.loglog(x, y1, "bo-", linewidth = 2, markersize = 12, label = "First") # label gives the name to the particular series
plt.loglog(x, y2, "gs-", linewidth = 2, markersize = 12, label = "Second") 
plt.xlabel('X')
plt.ylabel('Y')
plt.axis([-0.5, 10.5, -5, 105]) # [xmin, xmax, ymin, ymax]
plt.legend(loc = "upper left")
plt.savefig("mypracticeplot.pdf")
# Out:
# C:\Users\Rafael\Miniconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#
# C:\Users\Rafael\Miniconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.

# %%
x = np.logspace(0,1,10)
y = x**2
plt.loglog(x,y,"bo-")

# %% [markdown]
# # 2.3.4: Generating Histograms

# %% [markdown]
# There are many ways to generate histograms.
# Let's look at one of them, which is using the hist function from the plt library

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate 1,000 samples or draws from the standard normal distribution, which is a special case of the
# normal distribution that has mean equal to 0 and variance equal to 1.

x = np.random.normal(size = 1000)

# %%
plt.hist(x) # By default, hist uses 10 evenly spaced bins and it tries to optimize both bin width and bin locations.
# Out:
# (array([  8.,  38., 136., 221., 277., 205.,  82.,  27.,   5.,   1.]),
#  array([-3.09120347, -2.38340634, -1.67560921, -0.96781209, -0.26001496,
#          0.44778217,  1.1555793 ,  1.86337643,  2.57117356,  3.27897069,
#          3.98676782]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(x, normed=True); # no more normed property any more
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-98d035d2c653> in <module>
# ----> 1 plt.hist(x, normed=True);
#
# ~\Miniconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2593         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2594         color=color, label=label, stacked=stacked,
# -> 2595         **({"data": data} if data is not None else {}), **kwargs)
#    2596
#    2597
#
# ~\Miniconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
# ...

# %%
plt.hist(x, density=True, stacked=True) 
# instead of having the number of observations that fall in each bin, we have the proportion of observations 
# that fall in each bin. That's what it means for a histogram to be normalized.
# Out:
# (array([0.01130267, 0.0536877 , 0.19214545, 0.31223636, 0.39135508,
#         0.28963101, 0.11585241, 0.03814652, 0.00706417, 0.00141283]),
#  array([-3.09120347, -2.38340634, -1.67560921, -0.96781209, -0.26001496,
#          0.44778217,  1.1555793 ,  1.86337643,  2.57117356,  3.27897069,
#          3.98676782]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(x, density=True, stacked=True, bins=np.linspace(-5,5,21)); 
# To provide the location of the bins, we used a keyword argument called bins.
# I'm going to construct the bins using the np.linspace function.
# In this case, you see that the histogram looks different.
# That's because we have specified 20 bins between the numbers minus 5 and plus 5.
# So to get one bin, we need two points

# %% [markdown]
# Let's then examine another distribution, which is a bit more exotic, the so-called gamma distribution.
# It is a continuous probability density function that starts at 0 and goes all the way to positive infinity.
# In this case, we're going to draw a large number of samplesfrom the gamma distribution.
# Let's go with 100,000 samples which would give us a very smooth histogram.

# %% [markdown]
# We'll also meet here a plt function called
# subplot, which enables us to have several subplots within each figure.
# This upload function takes in three arguments where the first two specify
# the number of rows and the number of columns in the subplot,
# and the third argument gives the plot number.
# For example, if you specify two rows and three columns,
# then you will have six subplots.
# The plot number always starts at 1, so in a two by three subplot,
# the plot numbers range from 1 to 6, where the plot numbers
# are incremented across rows first.

# %%
x = np.random.gamma(2,3,100000)
    plt.hist(x, bins = 30);

# %%
plt.hist(x, bins = 30, density=True, stacked=True); # we normalize the histogram

# %%
plt.hist(x, bins = 30, cumulative = True); # we can also look at the cumulative histogram

# %%
plt.hist(x, bins = 30, density=True, stacked=True, cumulative = True); # normalized and cumulative

# %%
plt.hist(x, bins = 30, density=True, stacked=True, cumulative = True, histtype = "step"); # changed the histogram type

# %%
plt.figure()
plt.subplot(221)
plt.hist(x, bins = 30)
plt.subplot(222)
plt.hist(x, bins = 30, density=True, stacked=True)
plt.subplot(223)
plt.hist(x, bins = 30, cumulative = True)
plt.subplot(224)
plt.hist(x, bins = 30, density=True, stacked=True, cumulative = True, histtype = "step"); 

# In this case, we have created just one figure with four panels where each type of histogram appears in its own subplot.

# %% [markdown]
# Which will have wider bins, np.linspace(-5,5,21) or np.linspace(-5,5,201)?
# np.linspace(-5,5,21) correct
# np.linspace(-5,5,201) incorrec
#
# Explanation
#
# The third argument of np.linspace is the number of bins. As this number increases, the width of each bin decreases!
